# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import math
import scipy.optimize as sci
import pandas as pd

# %%
# CAPM line
def capm(rf, b, std):
    return rf + b* std

# %%
# utility function
def utility(std, offset):
    return 0.05* (std+1)**4 + offset

# %%
sns.set_style('dark')
steps = 100
std = np.linspace(0, 2, steps)
y_axis = 4.5
capm_line = []
utility_curve = []
utility_curve_second = []
utility_curve_third = []

for i in range(steps):
    capm_line.append(capm(rf=3, b=1.5, std=std[i]))
    utility_curve.append(utility(std=std[i], offset=3.72))
    #utility_curve_second.append(utility(std=std[i], offset=4.22))
    #utility_curve_third.append(utility(std=std[i], offset=3.22))


plt.figure(figsize=(10,8))
plt.plot(std, capm_line, color = 'black', label='CAPM line')
plt.plot(std, utility_curve, color = 'red', label='max. utility')
#plt.plot(std, utility_curve_second, color = 'red', alpha=0.2, linestyle='dashed')
#plt.plot(std, utility_curve_third, color = 'red', alpha=0.2, linestyle='dashed')
plt.hlines(y_axis, 0, 1, colors='red', linewidth = 0.8, linestyles='dashed', label="investor's optimal portfolio")
plt.vlines(1, 0, y_axis, colors='red', linewidth = 0.8, linestyles='dashed')
plt.xticks([])
plt.yticks([])
#plt.scatter(0, 3, color='red', zorder=5)
plt.text(-0.06, 2.98, r'$ \ r_{f}$', color='black', fontsize=14)
plt.text(-0.13, y_axis -0.02, r'$ \mu_{opt}$', color='black', fontsize=14)
plt.text(0.98, 1.85, r'$ \sigma_{opt}$', color='black', fontsize=14)
# market portfolio
plt.hlines(y_axis + 0.77, 0, 1.5, colors='black', linewidth = 0.8, linestyles='dashed', label='market portfolio')
plt.vlines(1.5, 0, y_axis +0.77, colors='black', linewidth = 0.8, linestyles='dashed')
plt.text(-0.13, y_axis +0.76, r'$ \mu_{m}$', color='black', fontsize=14)
plt.text(1.48, 1.85, r'$ \sigma_{m}$', color='black', fontsize=14)
plt.xlim(0, 2)
plt.ylim(2,8)
plt.xlabel('Risk', loc='right', fontsize=16)
plt.ylabel('Return', loc='top', fontsize=16)
plt.title('Capital Market Line and Optimal Portfolio Choice', fontsize=20)
plt.legend(fontsize=14)
plt.show()

# %%
capm_line[:80]
# Out:
# [3.0,
#  3.0303030303030303,
#  3.0606060606060606,
#  3.090909090909091,
#  3.121212121212121,
#  3.1515151515151514,
#  3.1818181818181817,
#  3.212121212121212,
#  3.242424242424242,
#  3.2727272727272725,
#  3.303030303030303,
#  3.3333333333333335,
#  3.3636363636363638,
#  3.393939393939394,
#  3.4242424242424243,
#  3.4545454545454546,
#  3.484848484848485,
#  3.515151515151515,
#  3.5454545454545454,
#  3.5757575757575757,
#  3.6060606060606064,
#  3.6363636363636362,
#  3.666666666666667,
#  3.6969696969696972,
#  3.7272727272727275,
#  3.757575757575758,
#  3.787878787878788,
#  3.8181818181818183,
#  3.8484848484848486,
#  3.878787878787879,
#  3.909090909090909,
#  3.9393939393939394,
#  3.9696969696969697,
#  4.0,
#  4.03030303030303,
#  4.0606060606060606,
#  4.090909090909091,
#  4.121212121212121,
#  4.151515151515151,
#  4.181818181818182,
#  4.212121212121213,
#  4.242424242424242,
#  4.2727272727272725,
#  4.303030303030303,
#  4.333333333333334,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the line equation parameters (y = mx + b)
m = 2  # slope
b = 3  # y-intercept

# Create x values
x = np.linspace(-10, 10, 400)

# Calculate y values
y = m * x + b

# Plot the line
plt.plot(x, y, label=f'y = {m}x + {b}')

# Mark the y-axis intercept
y_intercept = b
plt.scatter(0, y_intercept, color='red', zorder=5)
plt.text(0.2, y_intercept, f'({0}, {y_intercept})', color='red')

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Plot and Y-Axis Intercept')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()

# Show plot
plt.show()
